# %% [markdown]
# # ML Algorithms:

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Supervised Learning
#
# ---
# ---

# %% [markdown]
# ### Regression:

# %% [markdown]
# #### Regresion Lineal:
