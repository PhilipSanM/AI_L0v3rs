# %%
import sys

# %%
texto = open("./Raw_chats/_chat.txt", 'r', encoding="utf8")

# %%
texto = texto.readlines()

# %%
texto
# Out:
# ['[12/01/23, 4:03:12\u202fp.m.] Kemonitooo Escom: \u200eMessages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.\n',
#  '\u200e[12/01/23, 4:03:12\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '\u200e[12/01/23, 4:03:13\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '\u200e[12/01/23, 4:03:14\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '\u200e[12/01/23, 4:03:14\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '\u200e[12/01/23, 4:03:15\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '\u200e[12/01/23, 4:03:15\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '\u200e[12/01/23, 4:03:16\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '\u200e[12/01/23, 4:03:16\u202fp.m.] FelipeSan: \u200eimage omitted\n',
#  '[12/01/23, 4:03:34\u202fp.m.] FelipeSan: https://app.smartsheet.com/b/form/bb5b7858997645688c6f79b0daaf6333\n',
# ...

# %%
import pandas as pd

# %%
data = [
    {"Philips": ['Gracias Kemonitoo', 'Las lista 2 esta bn tardada'], 'Kemono': ['Aqui creeo estan resueltos casi todas las listas', 'Lo use para la ultima y me sirvio' ], 'Date': '26/03/23'}
]

my_df = pd.DataFrame(data)

# %%
my_df.head()
# Out:
#                                             Philips  \
# 0  [Gracias Kemonitoo, Las lista 2 esta bn tardada]
#
#                                               Kemono      Date
# 0  [Aqui creeo estan resueltos casi todas las lis...  26/03/23
