# %% [markdown]
# # Neurons

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Linear Regression:
# ![image.png](attachment:image.png)

# %% [markdown]
# Not all neuran connection are equal, weakers or strongers:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Action potentiol in a neuron, a signal, think about them about binary outputs, main calculation

# %% [markdown]
# There are binary classification

# %% [markdown]
# * All-or-nothing principle; a threshold

# %% [markdown]
# Each w^T tell us about the sigmoid function..

# %% [markdown]
# ## How does a model learn?

# %% [markdown]
# ---

# %% [markdown]
# MSE = error function for making a prediction:
# ![image.png](attachment:image.png)

# %% [markdown]
# And minimizing Cost for a function.

# %% [markdown]
# What if there is more than one variable?, gradient with respect :)

# %% [markdown]
# Find the gradient <<<

# %% [markdown]
# TensorFlow fin that gradient for us, of all my weights and use it to train ma model

# %% [markdown]
# Gradient Descent for knowing the minimun value in a function, like using bio-informatics

# %% [markdown]
# Also there is a learning rate and all..
